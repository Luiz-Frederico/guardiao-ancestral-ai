# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Instalação das Bibliotecas
# !pip install streamlit ultralytics folium streamlit-folium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.5/530.5 kB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 67.9 MB/s eta 0:00:00
# ...

# %%
# 1. Instalação necessária
# !pip install pyngrok

from google.colab import userdata
from pyngrok import ngrok
import os

# %%
# 1. Configura o token de segurança (oculto no "Secrets")
ngrok.set_auth_token(userdata.get('NGROK_TOKEN'))

# 2. Abre o túnel para a porta 8501 (onde o Streamlit roda)
public_url = ngrok.connect(8501)
print(f"✅ Dashboard online em: {public_url}")

# 3. Roda o Streamlit
# !streamlit run /content/drive/MyDrive/guardiao_ancestral/app.py --server.runOnSave true
# Out:
# ✅ Dashboard online em: NgrokTunnel: "https://popsicle-covenant-petunia.ngrok-free.dev" -> "http://localhost:8501"
#
# ...
#
# 2026-06-09 08:27:23.438 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.125.41:8501
#
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
